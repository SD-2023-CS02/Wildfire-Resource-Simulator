# %%
import pandas as pd
from sklearn.cluster import KMeans

# %%
IN_FOLDER = 'output'
IN_FILE = 'frontend_fire_data_no_nan'

# %%
fire_df = pd.read_csv(f'{IN_FOLDER}/{IN_FILE}.csv', index_col='UniqueFireIdentifier')
subset = fire_df[['FireDiscoveryDateTime', 'Latitude', 'Longitude']]

display(subset)
# Out:
#                        FireDiscoveryDateTime   Latitude   Longitude
# UniqueFireIdentifier
# 2014-AKFAS-411093     2014/05/12 03:06:19+00  64.802702 -147.745026
# 2014-AKMSS-401077     2014/05/09 03:22:55+00  61.103002 -149.663023
# 2014-AKKKS-403067     2014/05/05 00:18:25+00  60.295001 -151.262022
# 2014-AKMSS-401137     2014/05/19 21:45:02+00  62.422602 -150.081024
# 2014-AKMSS-401131     2014/05/19 00:01:00+00  61.543802 -148.879023
# ...                                      ...        ...         ...
# 2019-CAKNP-000165     2019/09/20 15:23:00+00  36.492025 -118.829513
# 2019-NVEKD-010335     2019/09/25 04:15:00+00  40.688173 -116.179680
# 2019-CAKNP-000172     2019/10/04 21:08:00+00  36.789975 -118.672913
# 2019-AZASD-000676     2019/10/09 16:12:00+00  36.691945 -114.022012
# 2020-NHWMF-000039     2020/05/21 17:00:00+00  44.003999  -71.666058
#
# [961 rows x 3 columns]
