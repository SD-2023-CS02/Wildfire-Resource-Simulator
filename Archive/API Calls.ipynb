# %% [markdown]
# # NASA Fire Information for Resource Management System (FIRMS) API
# | Attribute    | Short Description              | Long Description                                                                                                                                                                                                   |
# |--------------|--------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Satellite    | Satellite                      | L8 = Landsat 8; L9 = Landsat 9                                                                                                                                                                                     |
# | Latitude     | Latitude (decimal degrees)     | Latitude of pixel center                                                                                                                                                                                           |
# | Longitude    | Longitude (decimal degrees)    | Longitude of pixel center                                                                                                                                                                                          |
# | Path         | Path                           | Path number as identified in the World Reference System-2 (WRS-2)                                                                                                                                                  |
# | Row          | Row                            | Row number as identified in the World Reference System-2 (WRS-2)                                                                                                                                                   |
# | Track        | Track                          | The pixel location in the along-track dimension of the Landsat path based on the OLI Line-of-Sight (LOS) coordinate system. Generally increases in value from north to south for daytime and nighttime overpasses. |
# | Scan         | Scan                           | The pixel location in the cross-track dimension of the Landsat path based on the OLI Line-of-Sight (LOS) coordinate system. Generally increases in value from west to east for daytime and nighttime overpasses.   |
# | Acquire_Time | Date and time of start of scan | Date and time of acquisition/overpass of the satellite (in UTC). The format is YYYY-MM-DD followed by HH:MM-SS. For example, 2022-07-23 10:09:00.                                                                  |
# | Confidence   | Confidence                     | Value domain: H, M, and L: * H: Higher confidence * M: Medium confidence * L: Lower confidence                                                                                                                           |
# | Version      | Version (FIRMS reference only) | 1.0.7 NRT                                                                                                                                                                                                          |
# | DayNight     | Day or Night                   | D= Daytime fire, N= Nighttime fire                                                                                                                                                                                 |

# %%
from configparser import ConfigParser
import requests
import pandas as pd


config = ConfigParser()
config.read("config.ini")

key = config["API"]["MapKey"]
source = "LANDSAT_NRT"
day_range = 10

url = f"https://firms.modaps.eosdis.nasa.gov/api/country/csv/{key}/{source}/USA/{day_range}"
res = requests.get(url)

firms_data = "firms_data.csv"

with open(firms_data, "w") as f:
   f.write(res.text)

firms_df = pd.read_csv(firms_data)

display(firms_df)
# Out:
#       country_id   latitude   longitude  path  row  scan  track    acq_date  \
# 0            USA  39.874353  -80.699413    18   32  4934   5612  2023-10-07
# 1            USA  39.899811  -80.483474    18   32  5549   5515  2023-10-07
# 2            USA  40.271155  -79.987731    18   32  6946   4129  2023-10-07
# 3            USA  40.495145  -81.734656    18   32  2002   3308  2023-10-07
# 4            USA  40.558372  -81.778223    18   32  1881   3073  2023-10-07
# ...          ...        ...         ...   ...  ...   ...    ...         ...
# 22614        USA  36.745198 -118.863030    42   35  5803   1403  2023-10-15
# 22615        USA  36.746221 -118.866751    42   35  5792   1399  2023-10-15
# 22616        USA  36.746475 -118.867765    42   35  5789   1398  2023-10-15
# 22617        USA  36.750131 -118.858781    42   35  5816   1385  2023-10-15
# 22618        USA  36.792005 -120.255520    42   35  1664   1119  2023-10-15
#
#        acq_time satellite confidence daynight
# 0          1604        L9          H        D
# 1          1604        L9          L        D
# 2          1604        L9          H        D
# 3          1604        L9          H        D
# 4          1604        L9          H        D
# ...         ...       ...        ...      ...
# 22614      1834        L9          H        D
# 22615      1834        L9          L        D
# 22616      1834        L9          M        D
# 22617      1834        L9          M        D
# 22618      1834        L9          L        D
#
# [22619 rows x 12 columns]

# %% [markdown]
# ## Ambee API | Environmental Climate Data

# %%
# Ambee Weather at current time in Spokane

import json

with open('ambee_jsons/ambee_weather.json', 'r') as file:
    data = json.load(file)
    
print(json.dumps(data, indent=3))
# Out:
# {
#    "message": "success",
#    "data": {
#       "lat": 47.668331,
#       "lng": -117.402771,
#       "timezone": "America/Los_Angeles",
#       "country_code": "US",
#       "time": 1697061600,
#       "apparentTemperature": 47,
#       "cloudCover": 0.99,
#       "dewPoint": 39.34,
#       "humidity": 56,
#       "pressure": 1007,
#       "precipIntensity": 0,
#       "temperature": 54,
#       "visibility": 489.98,
#       "windGust": 8.57,
#       "ozone": 294.94,
#       "uvIndex": 0.42,
#       "windSpeed": 4.94,
#       "windBearing": 228,
#       "icon": "cloudy",
#       "summary": "Cloudy skies. A mild day ahead. Moderate humidity. Expect a gentle breeze. Low UV levels.",
#       "updatedAt": "2023-10-11T22:00:00.000Z"
#    }
# }

# %%
# Ambee Weather Forecaset in Spokane

with open('ambee_jsons/ambee_weather_forecast.json', 'r') as file:
    data = json.load(file)
    
print(json.dumps(data, indent=3))
# Out:
# {
#    "message": "success",
#    "data": {
#       "lat": 47.668331,
#       "lng": -117.402771,
#       "forecast": [
#          {
#             "time": 1697065200,
#             "dewPoint": 41.65,
#             "temperature": 53.51,
#             "apparentTemperature": 51.57,
#             "humidity": 64,
#             "pressure": 1008,
#             "windSpeed": 4.65,
#             "windBearing": 169,
#             "windGust": 8.52,
#             "cloudCover": 1,
#             "visibility": 10,
#             "uvIndex": 0.29,
#             "summary": "light rain",
#             "icon": "rain",
#             "precipType": "rain",
#             "precipIntensity": 0.12,
#             "ozone": 60.8
#          },
#          {
#             "time": 1697068800,
#             "dewPoint": 41.18,
#             "temperature": 54.32,
#             "apparentTemperature": 52.32,
#             "humidity": 61,
#             "pressure": 1008,
#             "windSpeed": 3.78,
#             "windBearing": 139,
#             "windGust": 6.51,
#             "cloudCover": 1,
#             "visibility": 10,
#             "uvIndex": 0.16,
#             "summary": "overcast clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 53.64
#          },
#          {
#             "time": 1697072400,
#             "dewPoint": 41.7,
#             "temperature": 53.56,
#             "apparentTemperature": 51.62,
#             "humidity": 64,
#             "pressure": 1008,
#             "windSpeed": 3.69,
#             "windBearing": 119,
#             "windGust": 5.44,
#             "cloudCover": 1,
#             "visibility": 10,
#             "uvIndex": 0.05,
#             "summary": "overcast clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 48.64
#          },
#          {
#             "time": 1697076000,
#             "dewPoint": 42.37,
#             "temperature": 52.61,
#             "apparentTemperature": 50.77,
#             "humidity": 68,
#             "pressure": 1009,
#             "windSpeed": 3.24,
#             "windBearing": 112,
#             "windGust": 5.1,
#             "cloudCover": 1,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "overcast clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 40.05
#          },
#          {
#             "time": 1697079600,
#             "dewPoint": 43.18,
#             "temperature": 51.53,
#             "apparentTemperature": 49.82,
#             "humidity": 73,
#             "pressure": 1010,
#             "windSpeed": 3.47,
#             "windBearing": 113,
#             "windGust": 5.32,
#             "cloudCover": 1,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "light rain",
#             "icon": "rain",
#             "precipType": "rain",
#             "precipIntensity": 0.11,
#             "ozone": 30.76
#          },
#          {
#             "time": 1697083200,
#             "dewPoint": 44.1,
#             "temperature": 50.34,
#             "apparentTemperature": 48.79,
#             "humidity": 79,
#             "pressure": 1010,
#             "windSpeed": 3.83,
#             "windBearing": 114,
#             "windGust": 6.06,
#             "cloudCover": 1,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "light rain",
#             "icon": "rain",
#             "precipType": "rain",
#             "precipIntensity": 0.2,
#             "ozone": 25.03
#          },
#          {
#             "time": 1697086800,
#             "dewPoint": 43.75,
#             "temperature": 49.23,
#             "apparentTemperature": 48.56,
#             "humidity": 84,
#             "pressure": 1012,
#             "windSpeed": 3.27,
#             "windBearing": 119,
#             "windGust": 5.5,
#             "cloudCover": 1,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "light rain",
#             "icon": "rain",
#             "precipType": "rain",
#             "precipIntensity": 0.11,
#             "ozone": 21.82
#          },
#          {
#             "time": 1697090400,
#             "dewPoint": 43.77,
#             "temperature": 49.12,
#             "apparentTemperature": 49.12,
#             "humidity": 85,
#             "pressure": 1012,
#             "windSpeed": 2.75,
#             "windBearing": 107,
#             "windGust": 4.68,
#             "cloudCover": 1,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "overcast clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 19.85
#          },
#          {
#             "time": 1697094000,
#             "dewPoint": 43.75,
#             "temperature": 49.01,
#             "apparentTemperature": 49.01,
#             "humidity": 85,
#             "pressure": 1013,
#             "windSpeed": 2.62,
#             "windBearing": 98,
#             "windGust": 4.18,
#             "cloudCover": 1,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "overcast clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 18.95
#          },
#          {
#             "time": 1697097600,
#             "dewPoint": 43.77,
#             "temperature": 48.94,
#             "apparentTemperature": 48.94,
#             "humidity": 85,
#             "pressure": 1014,
#             "windSpeed": 2.04,
#             "windBearing": 93,
#             "windGust": 3.29,
#             "cloudCover": 0.99,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "overcast clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 19.31
#          },
#          {
#             "time": 1697101200,
#             "dewPoint": 43.74,
#             "temperature": 48.9,
#             "apparentTemperature": 48.9,
#             "humidity": 85,
#             "pressure": 1014,
#             "windSpeed": 1.99,
#             "windBearing": 93,
#             "windGust": 3,
#             "cloudCover": 0.97,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "overcast clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 20.21
#          },
#          {
#             "time": 1697104800,
#             "dewPoint": 43.68,
#             "temperature": 48.52,
#             "apparentTemperature": 48.52,
#             "humidity": 86,
#             "pressure": 1015,
#             "windSpeed": 1.41,
#             "windBearing": 96,
#             "windGust": 2.3,
#             "cloudCover": 0.87,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "overcast clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 21.99
#          },
#          {
#             "time": 1697108400,
#             "dewPoint": 43,
#             "temperature": 47.44,
#             "apparentTemperature": 47.44,
#             "humidity": 88,
#             "pressure": 1016,
#             "windSpeed": 1.32,
#             "windBearing": 62,
#             "windGust": 2.19,
#             "cloudCover": 0.77,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "broken clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 28.25
#          },
#          {
#             "time": 1697112000,
#             "dewPoint": 42.48,
#             "temperature": 46.85,
#             "apparentTemperature": 46.85,
#             "humidity": 88,
#             "pressure": 1016,
#             "windSpeed": 1.41,
#             "windBearing": 19,
#             "windGust": 2.39,
#             "cloudCover": 0.68,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "broken clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 32.19
#          },
#          {
#             "time": 1697115600,
#             "dewPoint": 41.99,
#             "temperature": 46.33,
#             "apparentTemperature": 46.33,
#             "humidity": 88,
#             "pressure": 1017,
#             "windSpeed": 1.59,
#             "windBearing": 15,
#             "windGust": 2.51,
#             "cloudCover": 0.63,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "broken clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 32.54
#          },
#          {
#             "time": 1697119200,
#             "dewPoint": 41.32,
#             "temperature": 45.46,
#             "apparentTemperature": 45.46,
#             "humidity": 88,
#             "pressure": 1018,
#             "windSpeed": 1.5,
#             "windBearing": 47,
#             "windGust": 2.1,
#             "cloudCover": 0.31,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "scattered clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 29.68
#          },
#          {
#             "time": 1697122800,
#             "dewPoint": 40.71,
#             "temperature": 44.78,
#             "apparentTemperature": 44.78,
#             "humidity": 89,
#             "pressure": 1019,
#             "windSpeed": 1.92,
#             "windBearing": 31,
#             "windGust": 2.48,
#             "cloudCover": 0.23,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "few clouds",
#             "icon": "partly-cloudy-night",
#             "precipIntensity": 0,
#             "ozone": 25.03
#          },
#          {
#             "time": 1697126400,
#             "dewPoint": 40.84,
#             "temperature": 45.77,
#             "apparentTemperature": 45.77,
#             "humidity": 86,
#             "pressure": 1020,
#             "windSpeed": 2.21,
#             "windBearing": 13,
#             "windGust": 2.55,
#             "cloudCover": 0.18,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "few clouds",
#             "icon": "partly-cloudy-day",
#             "precipIntensity": 0,
#             "ozone": 21.1
#          },
#          {
#             "time": 1697130000,
#             "dewPoint": 41.07,
#             "temperature": 48.58,
#             "apparentTemperature": 48.58,
#             "humidity": 78,
#             "pressure": 1020,
#             "windSpeed": 2.57,
#             "windBearing": 7,
#             "windGust": 2.8,
#             "cloudCover": 0.15,
#             "visibility": 10,
#             "uvIndex": 0.49,
#             "summary": "few clouds",
#             "icon": "partly-cloudy-day",
#             "precipIntensity": 0,
#             "ozone": 19.49
#          },
#          {
#             "time": 1697133600,
#             "dewPoint": 41.29,
#             "temperature": 51.49,
#             "apparentTemperature": 49.64,
#             "humidity": 70,
#             "pressure": 1019,
#             "windSpeed": 2.77,
#             "windBearing": 34,
#             "windGust": 2.93,
#             "cloudCover": 0.14,
#             "visibility": 10,
#             "uvIndex": 1.2,
#             "summary": "few clouds",
#             "icon": "partly-cloudy-day",
#             "precipIntensity": 0,
#             "ozone": 19.67
#          },
#          {
#             "time": 1697137200,
#             "dewPoint": 40.6,
#             "temperature": 54.25,
#             "apparentTemperature": 52.29,
#             "humidity": 62,
#             "pressure": 1019,
#             "windSpeed": 2.82,
#             "windBearing": 47,
#             "windGust": 3.33,
#             "cloudCover": 0.13,
#             "visibility": 10,
#             "uvIndex": 2.04,
#             "summary": "few clouds",
#             "icon": "partly-cloudy-day",
#             "precipIntensity": 0,
#             "ozone": 20.39
#          },
#          {
#             "time": 1697140800,
#             "dewPoint": 39.52,
#             "temperature": 56.62,
#             "apparentTemperature": 54.52,
#             "humidity": 54,
#             "pressure": 1019,
#             "windSpeed": 2.59,
#             "windBearing": 38,
#             "windGust": 3.44,
#             "cloudCover": 0.08,
#             "visibility": 10,
#             "uvIndex": 2.7,
#             "summary": "clear sky",
#             "icon": "clear-day",
#             "precipIntensity": 0,
#             "ozone": 50.07
#          },
#          {
#             "time": 1697144400,
#             "dewPoint": 38.34,
#             "temperature": 58.33,
#             "apparentTemperature": 56.17,
#             "humidity": 49,
#             "pressure": 1018,
#             "windSpeed": 2.86,
#             "windBearing": 29,
#             "windGust": 4.23,
#             "cloudCover": 0.08,
#             "visibility": 10,
#             "uvIndex": 2.89,
#             "summary": "clear sky",
#             "icon": "clear-day",
#             "precipIntensity": 0,
#             "ozone": 60.8
#          },
#          {
#             "time": 1697148000,
#             "dewPoint": 37.69,
#             "temperature": 59.67,
#             "apparentTemperature": 57.45,
#             "humidity": 45,
#             "pressure": 1018,
#             "windSpeed": 3.38,
#             "windBearing": 26,
#             "windGust": 5.26,
#             "cloudCover": 0.07,
#             "visibility": 10,
#             "uvIndex": 2.52,
#             "summary": "clear sky",
#             "icon": "clear-day",
#             "precipIntensity": 0,
#             "ozone": 65.09
#          },
#          {
#             "time": 1697151600,
#             "dewPoint": 37.42,
#             "temperature": 60.37,
#             "apparentTemperature": 58.17,
#             "humidity": 44,
#             "pressure": 1017,
#             "windSpeed": 3.62,
#             "windBearing": 38,
#             "windGust": 6.42,
#             "cloudCover": 0.09,
#             "visibility": 10,
#             "uvIndex": 1.79,
#             "summary": "clear sky",
#             "icon": "clear-day",
#             "precipIntensity": 0,
#             "ozone": 62.23
#          },
#          {
#             "time": 1697155200,
#             "dewPoint": 37.13,
#             "temperature": 60.62,
#             "apparentTemperature": 58.41,
#             "humidity": 43,
#             "pressure": 1017,
#             "windSpeed": 3.94,
#             "windBearing": 41,
#             "windGust": 7.38,
#             "cloudCover": 0.09,
#             "visibility": 10,
#             "uvIndex": 0.94,
#             "summary": "clear sky",
#             "icon": "clear-day",
#             "precipIntensity": 0,
#             "ozone": 57.22
#          },
#          {
#             "time": 1697158800,
#             "dewPoint": 37.6,
#             "temperature": 60.03,
#             "apparentTemperature": 57.85,
#             "humidity": 45,
#             "pressure": 1016,
#             "windSpeed": 4.16,
#             "windBearing": 30,
#             "windGust": 7.2,
#             "cloudCover": 0.08,
#             "visibility": 10,
#             "uvIndex": 0.32,
#             "summary": "clear sky",
#             "icon": "clear-day",
#             "precipIntensity": 0,
#             "ozone": 55.79
#          },
#          {
#             "time": 1697162400,
#             "dewPoint": 37.4,
#             "temperature": 56.37,
#             "apparentTemperature": 54.1,
#             "humidity": 51,
#             "pressure": 1016,
#             "windSpeed": 3.76,
#             "windBearing": 18,
#             "windGust": 5.3,
#             "cloudCover": 0.04,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "clear sky",
#             "icon": "clear-day",
#             "precipIntensity": 0,
#             "ozone": 55.08
#          },
#          {
#             "time": 1697166000,
#             "dewPoint": 37.33,
#             "temperature": 54.32,
#             "apparentTemperature": 52,
#             "humidity": 54,
#             "pressure": 1016,
#             "windSpeed": 4.05,
#             "windBearing": 29,
#             "windGust": 5.64,
#             "cloudCover": 0.04,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "clear sky",
#             "icon": "clear-night",
#             "precipIntensity": 0,
#             "ozone": 48.64
#          },
#          {
#             "time": 1697169600,
#             "dewPoint": 37.2,
#             "temperature": 53.24,
#             "apparentTemperature": 50.9,
#             "humidity": 56,
#             "pressure": 1017,
#             "windSpeed": 4.12,
#             "windBearing": 17,
#             "windGust": 4.88,
#             "cloudCover": 0.12,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "few clouds",
#             "icon": "partly-cloudy-night",
#             "precipIntensity": 0,
#             "ozone": 39.34
#          },
#          {
#             "time": 1697173200,
#             "dewPoint": 37.13,
#             "temperature": 52.21,
#             "apparentTemperature": 49.86,
#             "humidity": 58,
#             "pressure": 1017,
#             "windSpeed": 4.34,
#             "windBearing": 18,
#             "windGust": 5.75,
#             "cloudCover": 0.24,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "few clouds",
#             "icon": "partly-cloudy-night",
#             "precipIntensity": 0,
#             "ozone": 28.61
#          },
#          {
#             "time": 1697176800,
#             "dewPoint": 37.18,
#             "temperature": 51.3,
#             "apparentTemperature": 48.94,
#             "humidity": 60,
#             "pressure": 1016,
#             "windSpeed": 4,
#             "windBearing": 29,
#             "windGust": 5.68,
#             "cloudCover": 0.34,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "scattered clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 17.7
#          },
#          {
#             "time": 1697180400,
#             "dewPoint": 37.24,
#             "temperature": 50.47,
#             "apparentTemperature": 48.18,
#             "humidity": 63,
#             "pressure": 1016,
#             "windSpeed": 3.78,
#             "windBearing": 25,
#             "windGust": 5.39,
#             "cloudCover": 0.42,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "scattered clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 9.3
#          },
#          {
#             "time": 1697184000,
#             "dewPoint": 37.35,
#             "temperature": 49.66,
#             "apparentTemperature": 48.6,
#             "humidity": 65,
#             "pressure": 1016,
#             "windSpeed": 3.83,
#             "windBearing": 32,
#             "windGust": 5.17,
#             "cloudCover": 0.55,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "broken clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 5.14
#          },
#          {
#             "time": 1697187600,
#             "dewPoint": 37.42,
#             "temperature": 48.87,
#             "apparentTemperature": 47.52,
#             "humidity": 67,
#             "pressure": 1016,
#             "windSpeed": 4.07,
#             "windBearing": 42,
#             "windGust": 5.99,
#             "cloudCover": 0.5,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "scattered clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 3.8
#          },
#          {
#             "time": 1697191200,
#             "dewPoint": 37.42,
#             "temperature": 48.16,
#             "apparentTemperature": 46.85,
#             "humidity": 69,
#             "pressure": 1016,
#             "windSpeed": 3.87,
#             "windBearing": 36,
#             "windGust": 5.73,
#             "cloudCover": 0.52,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "broken clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 5.36
#          },
#          {
#             "time": 1697194800,
#             "dewPoint": 37.27,
#             "temperature": 47.5,
#             "apparentTemperature": 46.27,
#             "humidity": 70,
#             "pressure": 1015,
#             "windSpeed": 3.62,
#             "windBearing": 47,
#             "windGust": 4.9,
#             "cloudCover": 0.47,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "scattered clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 12.34
#          },
#          {
#             "time": 1697198400,
#             "dewPoint": 37.09,
#             "temperature": 46.9,
#             "apparentTemperature": 45.93,
#             "humidity": 71,
#             "pressure": 1015,
#             "windSpeed": 3.24,
#             "windBearing": 48,
#             "windGust": 4.21,
#             "cloudCover": 0.39,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "scattered clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 16.63
#          },
#          {
#             "time": 1697202000,
#             "dewPoint": 36.9,
#             "temperature": 46.35,
#             "apparentTemperature": 45.5,
#             "humidity": 72,
#             "pressure": 1015,
#             "windSpeed": 3.04,
#             "windBearing": 57,
#             "windGust": 3.89,
#             "cloudCover": 0.32,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "scattered clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 17.52
#          },
#          {
#             "time": 1697205600,
#             "dewPoint": 36.73,
#             "temperature": 45.9,
#             "apparentTemperature": 44.85,
#             "humidity": 73,
#             "pressure": 1015,
#             "windSpeed": 3.18,
#             "windBearing": 65,
#             "windGust": 3.96,
#             "cloudCover": 0,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "clear sky",
#             "icon": "clear-night",
#             "precipIntensity": 0,
#             "ozone": 18.95
#          },
#          {
#             "time": 1697209200,
#             "dewPoint": 36.5,
#             "temperature": 45.5,
#             "apparentTemperature": 44.1,
#             "humidity": 73,
#             "pressure": 1015,
#             "windSpeed": 3.51,
#             "windBearing": 66,
#             "windGust": 4.54,
#             "cloudCover": 0,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "clear sky",
#             "icon": "clear-night",
#             "precipIntensity": 0,
#             "ozone": 21.28
#          },
#          {
#             "time": 1697212800,
#             "dewPoint": 36.61,
#             "temperature": 46.71,
#             "apparentTemperature": 45.46,
#             "humidity": 70,
#             "pressure": 1015,
#             "windSpeed": 3.51,
#             "windBearing": 65,
#             "windGust": 6.17,
#             "cloudCover": 0,
#             "visibility": 10,
#             "uvIndex": 0,
#             "summary": "clear sky",
#             "icon": "clear-day",
#             "precipIntensity": 0,
#             "ozone": 22.35
#          },
#          {
#             "time": 1697216400,
#             "dewPoint": 36.66,
#             "temperature": 50.41,
#             "apparentTemperature": 48.02,
#             "humidity": 61,
#             "pressure": 1015,
#             "windSpeed": 3.71,
#             "windBearing": 69,
#             "windGust": 6.51,
#             "cloudCover": 0,
#             "visibility": 10,
#             "uvIndex": 0.5,
#             "summary": "clear sky",
#             "icon": "clear-day",
#             "precipIntensity": 0,
#             "ozone": 25.03
#          },
#          {
#             "time": 1697220000,
#             "dewPoint": 36.75,
#             "temperature": 54.5,
#             "apparentTemperature": 52.14,
#             "humidity": 53,
#             "pressure": 1014,
#             "windSpeed": 4.36,
#             "windBearing": 75,
#             "windGust": 7.47,
#             "cloudCover": 0,
#             "visibility": 10,
#             "uvIndex": 1.21,
#             "summary": "clear sky",
#             "icon": "clear-day",
#             "precipIntensity": 0,
#             "ozone": 30.76
#          },
#          {
#             "time": 1697223600,
#             "dewPoint": 36.82,
#             "temperature": 58.39,
#             "apparentTemperature": 56.08,
#             "humidity": 46,
#             "pressure": 1014,
#             "windSpeed": 4.16,
#             "windBearing": 80,
#             "windGust": 7.61,
#             "cloudCover": 0,
#             "visibility": 10,
#             "uvIndex": 2.08,
#             "summary": "clear sky",
#             "icon": "clear-day",
#             "precipIntensity": 0,
#             "ozone": 41.49
#          },
#          {
#             "time": 1697227200,
#             "dewPoint": 36.79,
#             "temperature": 61.54,
#             "apparentTemperature": 59.32,
#             "humidity": 41,
#             "pressure": 1013,
#             "windSpeed": 4.92,
#             "windBearing": 93,
#             "windGust": 7.78,
#             "cloudCover": 0.01,
#             "visibility": 10,
#             "uvIndex": 2.87,
#             "summary": "clear sky",
#             "icon": "clear-day",
#             "precipIntensity": 0,
#             "ozone": 60.8
#          },
#          {
#             "time": 1697230800,
#             "dewPoint": 36.5,
#             "temperature": 64.17,
#             "apparentTemperature": 62.02,
#             "humidity": 37,
#             "pressure": 1012,
#             "windSpeed": 4.9,
#             "windBearing": 113,
#             "windGust": 7.87,
#             "cloudCover": 0.03,
#             "visibility": 10,
#             "uvIndex": 3.07,
#             "summary": "clear sky",
#             "icon": "clear-day",
#             "precipIntensity": 0,
#             "ozone": 68.67
#          },
#          {
#             "time": 1697234400,
#             "dewPoint": 35.94,
#             "temperature": 65.77,
#             "apparentTemperature": 63.64,
#             "humidity": 34,
#             "pressure": 1011,
#             "windSpeed": 4.9,
#             "windBearing": 121,
#             "windGust": 8.61,
#             "cloudCover": 0.29,
#             "visibility": 10,
#             "uvIndex": 2.67,
#             "summary": "scattered clouds",
#             "icon": "cloudy",
#             "precipIntensity": 0,
#             "ozone": 71.53
#          }
#       ]
#    }
# }

# %%
# Ambee API Active Fire Data -> South of Kennewick, WA

with open('ambee_jsons/ambee_fire.json', 'r') as file:
    data = json.load(file)
    
print(json.dumps(data, indent=3))
# Out:
# {
#    "message": "success",
#    "result": [
#       {
#          "fwi": 0.0009818224969113,
#          "cause": 0,
#          "size": 643.343004661987,
#          "lat": 45.90185221133077,
#          "lng": -119.28322026385962,
#          "burnedArea": 643.343004661987,
#          "frp": 2.37,
#          "fuelType": "0",
#          "percentContained": 0,
#          "fireId": "nifc_18321.0",
#          "createdAt": "2023-10-02T16:08:38.000Z",
#          "updatedAt": "2023-10-11T22:00:14.000Z",
#          "status": "Partially Contained Fire",
#          "risk": "High Danger",
#          "timeFlag": "Day",
#          "reportedLat": 45.918186,
#          "reportedLon": -119.319894,
#          "type": "Reported Fire",
#          "ros": 0,
#          "reportedLoc": {
#             "type": "Point",
#             "coordinates": [
#                -119.319894,
#                45.918186
#             ]
#          }
#       }
#    ]
# }

# %%
# Ambee API Active Fire Forecast -> South of Kennewick, WA
# Data shows month of October and November

with open('ambee_jsons/ambee_fire_forecast.json', 'r') as file:
    data = json.load(file)
    
print(json.dumps(data, indent=3))
# Out:
# {
#    "message": "success",
#    "result": [
#       {
#          "lat": 46,
#          "year": 2023,
#          "month": 10,
#          "fireRiskLevel": 2,
#          "fireRiskDanger": "Moderate Danger",
#          "createdFor": "2023-10-01T00:00:00.000Z",
#          "region": "NAR",
#          "lng": -119.0625
#       },
#       {
#          "lat": 46,
#          "year": 2023,
#          "month": 11,
#          "fireRiskLevel": 0,
#          "fireRiskDanger": "Very Low Danger",
#          "createdFor": "2023-11-01T00:00:00.000Z",
#          "region": "NAR",
#          "lng": -119.0625
#       }
#    ]
# }

# %%
# Ambee General Environmental Information in Spokane

with open('ambee_jsons/ambee_general.json', 'r') as file:
    data = json.load(file)
    
print(json.dumps(data, indent=3))
# Out:
# {
#    "message": "success",
#    "stations": [
#       {
#          "CO": 0.153,
#          "NO2": 5.722,
#          "OZONE": 28.03,
#          "PM10": 9.361,
#          "PM25": 3.17,
#          "SO2": 1.288,
#          "city": "Spokane",
#          "countryCode": "US",
#          "division": "Spokane",
#          "lat": 47.64999999999219,
#          "lng": -117.39999999998577,
#          "placeName": "E Hartson Ave",
#          "postalCode": "99202-2334",
#          "state": "Washington",
#          "updatedAt": "2023-10-11T19:00:00.000Z",
#          "AQI": 26,
#          "aqiInfo": {
#             "pollutant": "O3",
#             "concentration": 28.03,
#             "category": "Good"
#          }
#       }
#    ]
# }
